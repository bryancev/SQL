# %%
from datetime import datetime, timedelta
import pandas as pd
import psycopg2
from psycopg2.extras import RealDictCursor

# %%
POSTGRES = {
    'dbname': 'postgres',
    'user': 'postgres',
    'password': 'postgres',
    'host': '127.0.0.1',
    'port': 5432,
}

# %%
class Postgres:
    def __init__(self):
        try:
            self._conn = psycopg2.connect(**POSTGRES)
        except Exception as conn_error:
            print(conn_error)
            raise conn_error
        self._conn.set_client_encoding('UTF8')

    def execute(self, sql_give, args=None):
        if args is None:
            args = {}

        with self._conn.cursor(cursor_factory=RealDictCursor) as cursor:
            if isinstance(args, list):
                for i in args:
                    cursor.execute(sql_give, i)
            else:
                cursor.execute(sql_give, args)
        self._conn.commit()

    @classmethod
    def fetchall(cls, sql_give):
        pg = cls()
        try:
            return pg._fetchall(sql_give)
        except psycopg2.Error as fetch_error:
            print(fetch_error)
        finally:
            pg.close()

    def _fetchall(self, sql_give):
        with self._conn.cursor(cursor_factory=RealDictCursor) as cursor:
            cursor.execute(sql_give)
            return cursor.fetchall()

    def close(self):
        self._conn.close()

# %% [markdown]
# ### Посмотреть общую схему таблиц в базе данных

# %%
get_schema_sql = """
SELECT table_schema, table_name
FROM information_schema.tables
ORDER BY table_schema,table_name;
"""
conn = Postgres()
data = pd.DataFrame(
     conn.fetchall(get_schema_sql)
     )
conn.close()

for table_schema in data.table_schema.unique():
    print(data[data['table_schema'] == table_schema].to_markdown(), end='\n \n')
# Out:
# |    | table_schema       | table_name                            |
# |---:|:-------------------|:--------------------------------------|
# |  0 | information_schema | _pg_foreign_data_wrappers             |
# |  1 | information_schema | _pg_foreign_servers                   |
# |  2 | information_schema | _pg_foreign_table_columns             |
# |  3 | information_schema | _pg_foreign_tables                    |
# |  4 | information_schema | _pg_user_mappings                     |
# |  5 | information_schema | administrable_role_authorizations     |
# |  6 | information_schema | applicable_roles                      |
# |  7 | information_schema | attributes                            |
# |  8 | information_schema | character_sets                        |
# |  9 | information_schema | check_constraint_routine_usage        |
# | 10 | information_schema | check_constraints                     |
# | 11 | information_schema | collation_character_set_applicability |
# | 12 | information_schema | collations                            |
# | 13 | information_schema | column_column_usage                   |
# | 14 | information_schema | column_domain_usage                   |
# | 15 | information_schema | column_options                        |
# | 16 | information_schema | column_privileges                     |
# | 17 | information_schema | column_udt_usage                      |
# | 18 | information_schema | columns                               |
# | 19 | information_schema | constraint_column_usage               |
# | 20 | information_schema | constraint_table_usage                |
# | 21 | information_schema | data_type_privileges                  |
# | 22 | information_schema | domain_constraints                    |
# | 23 | information_schema | domain_udt_usage                      |
# | 24 | information_schema | domains                               |
# | 25 | information_schema | element_types                         |
# | 26 | information_schema | enabled_roles                         |
# | 27 | information_schema | foreign_data_wrapper_options          |
# | 28 | information_schema | foreign_data_wrappers                 |
# | 29 | information_schema | foreign_server_options                |
# | 30 | information_schema | foreign_servers                       |
# | 31 | information_schema | foreign_table_options                 |
# | 32 | information_schema | foreign_tables                        |
# | 33 | information_schema | information_schema_catalog_name       |
# | 34 | information_schema | key_column_usage                      |
# | 35 | information_schema | parameters                            |
# | 36 | information_schema | referential_constraints               |
# | 37 | information_schema | role_column_grants                    |
# | 38 | information_schema | role_routine_grants                   |
# | 39 | information_schema | role_table_grants                     |
# | 40 | information_schema | role_udt_grants                       |
# | 41 | information_schema | role_usage_grants                     |
# | 42 | information_schema | routine_column_usage                  |
# | 43 | information_schema | routine_privileges                    |
# | 44 | information_schema | routine_routine_usage                 |
# | 45 | information_schema | routine_sequence_usage                |
# | 46 | information_schema | routine_table_usage                   |
# | 47 | information_schema | routines                              |
# | 48 | information_schema | schemata                              |
# | 49 | information_schema | sequences                             |
# | 50 | information_schema | sql_features                          |
# | 51 | information_schema | sql_implementation_info               |
# | 52 | information_schema | sql_parts                             |
# | 53 | information_schema | sql_sizing                            |
# | 54 | information_schema | table_constraints                     |
# | 55 | information_schema | table_privileges                      |
# | 56 | information_schema | tables                                |
# | 57 | information_schema | transforms                            |
# | 58 | information_schema | triggered_update_columns              |
# | 59 | information_schema | triggers                              |
# | 60 | information_schema | udt_privileges                        |
# | 61 | information_schema | usage_privileges                      |
# | 62 | information_schema | user_defined_types                    |
# | 63 | information_schema | user_mapping_options                  |
# | 64 | information_schema | user_mappings                         |
# | 65 | information_schema | view_column_usage                     |
# | 66 | information_schema | view_routine_usage                    |
# | 67 | information_schema | view_table_usage                      |
# | 68 | information_schema | views                                 |
#
# |     | table_schema   | table_name                      |
# |----:|:---------------|:--------------------------------|
# |  69 | pg_catalog     | pg_aggregate                    |
# |  70 | pg_catalog     | pg_am                           |
# |  71 | pg_catalog     | pg_amop                         |
# |  72 | pg_catalog     | pg_amproc                       |
# |  73 | pg_catalog     | pg_attrdef                      |
# |  74 | pg_catalog     | pg_attribute                    |
# |  75 | pg_catalog     | pg_auth_members                 |
# |  76 | pg_catalog     | pg_authid                       |
# |  77 | pg_catalog     | pg_available_extension_versions |
# |  78 | pg_catalog     | pg_available_extensions         |
# |  79 | pg_catalog     | pg_backend_memory_contexts      |
# |  80 | pg_catalog     | pg_cast                         |
# |  81 | pg_catalog     | pg_class                        |
# |  82 | pg_catalog     | pg_collation                    |
# |  83 | pg_catalog     | pg_config                       |
# |  84 | pg_catalog     | pg_constraint                   |
# |  85 | pg_catalog     | pg_conversion                   |
# |  86 | pg_catalog     | pg_cursors                      |
# |  87 | pg_catalog     | pg_database                     |
# |  88 | pg_catalog     | pg_db_role_setting              |
# |  89 | pg_catalog     | pg_default_acl                  |
# |  90 | pg_catalog     | pg_depend                       |
# |  91 | pg_catalog     | pg_description                  |
# |  92 | pg_catalog     | pg_enum                         |
# |  93 | pg_catalog     | pg_event_trigger                |
# |  94 | pg_catalog     | pg_extension                    |
# |  95 | pg_catalog     | pg_file_settings                |
# |  96 | pg_catalog     | pg_foreign_data_wrapper         |
# |  97 | pg_catalog     | pg_foreign_server               |
# |  98 | pg_catalog     | pg_foreign_table                |
# |  99 | pg_catalog     | pg_group                        |
# | 100 | pg_catalog     | pg_hba_file_rules               |
# | 101 | pg_catalog     | pg_ident_file_mappings          |
# | 102 | pg_catalog     | pg_index                        |
# | 103 | pg_catalog     | pg_indexes                      |
# | 104 | pg_catalog     | pg_inherits                     |
# | 105 | pg_catalog     | pg_init_privs                   |
# | 106 | pg_catalog     | pg_language                     |
# | 107 | pg_catalog     | pg_largeobject                  |
# | 108 | pg_catalog     | pg_largeobject_metadata         |
# | 109 | pg_catalog     | pg_locks                        |
# | 110 | pg_catalog     | pg_matviews                     |
# | 111 | pg_catalog     | pg_namespace                    |
# | 112 | pg_catalog     | pg_opclass                      |
# | 113 | pg_catalog     | pg_operator                     |
# | 114 | pg_catalog     | pg_opfamily                     |
# | 115 | pg_catalog     | pg_parameter_acl                |
# | 116 | pg_catalog     | pg_partitioned_table            |
# | 117 | pg_catalog     | pg_policies                     |
# | 118 | pg_catalog     | pg_policy                       |
# | 119 | pg_catalog     | pg_prepared_statements          |
# | 120 | pg_catalog     | pg_prepared_xacts               |
# | 121 | pg_catalog     | pg_proc                         |
# | 122 | pg_catalog     | pg_publication                  |
# | 123 | pg_catalog     | pg_publication_namespace        |
# | 124 | pg_catalog     | pg_publication_rel              |
# | 125 | pg_catalog     | pg_publication_tables           |
# | 126 | pg_catalog     | pg_range                        |
# | 127 | pg_catalog     | pg_replication_origin           |
# | 128 | pg_catalog     | pg_replication_origin_status    |
# | 129 | pg_catalog     | pg_replication_slots            |
# | 130 | pg_catalog     | pg_rewrite                      |
# | 131 | pg_catalog     | pg_roles                        |
# | 132 | pg_catalog     | pg_rules                        |
# | 133 | pg_catalog     | pg_seclabel                     |
# | 134 | pg_catalog     | pg_seclabels                    |
# | 135 | pg_catalog     | pg_sequence                     |
# | 136 | pg_catalog     | pg_sequences                    |
# | 137 | pg_catalog     | pg_settings                     |
# | 138 | pg_catalog     | pg_shadow                       |
# | 139 | pg_catalog     | pg_shdepend                     |
# | 140 | pg_catalog     | pg_shdescription                |
# | 141 | pg_catalog     | pg_shmem_allocations            |
# | 142 | pg_catalog     | pg_shseclabel                   |
# | 143 | pg_catalog     | pg_stat_activity                |
# | 144 | pg_catalog     | pg_stat_all_indexes             |
# | 145 | pg_catalog     | pg_stat_all_tables              |
# | 146 | pg_catalog     | pg_stat_archiver                |
# | 147 | pg_catalog     | pg_stat_bgwriter                |
# | 148 | pg_catalog     | pg_stat_database                |
# | 149 | pg_catalog     | pg_stat_database_conflicts      |
# | 150 | pg_catalog     | pg_stat_gssapi                  |
# | 151 | pg_catalog     | pg_stat_io                      |
# | 152 | pg_catalog     | pg_stat_progress_analyze        |
# | 153 | pg_catalog     | pg_stat_progress_basebackup     |
# | 154 | pg_catalog     | pg_stat_progress_cluster        |
# | 155 | pg_catalog     | pg_stat_progress_copy           |
# | 156 | pg_catalog     | pg_stat_progress_create_index   |
# | 157 | pg_catalog     | pg_stat_progress_vacuum         |
# | 158 | pg_catalog     | pg_stat_recovery_prefetch       |
# | 159 | pg_catalog     | pg_stat_replication             |
# | 160 | pg_catalog     | pg_stat_replication_slots       |
# | 161 | pg_catalog     | pg_stat_slru                    |
# | 162 | pg_catalog     | pg_stat_ssl                     |
# | 163 | pg_catalog     | pg_stat_subscription            |
# | 164 | pg_catalog     | pg_stat_subscription_stats      |
# | 165 | pg_catalog     | pg_stat_sys_indexes             |
# | 166 | pg_catalog     | pg_stat_sys_tables              |
# | 167 | pg_catalog     | pg_stat_user_functions          |
# | 168 | pg_catalog     | pg_stat_user_indexes            |
# | 169 | pg_catalog     | pg_stat_user_tables             |
# | 170 | pg_catalog     | pg_stat_wal                     |
# | 171 | pg_catalog     | pg_stat_wal_receiver            |
# | 172 | pg_catalog     | pg_stat_xact_all_tables         |
# | 173 | pg_catalog     | pg_stat_xact_sys_tables         |
# | 174 | pg_catalog     | pg_stat_xact_user_functions     |
# | 175 | pg_catalog     | pg_stat_xact_user_tables        |
# | 176 | pg_catalog     | pg_statio_all_indexes           |
# | 177 | pg_catalog     | pg_statio_all_sequences         |
# | 178 | pg_catalog     | pg_statio_all_tables            |
# | 179 | pg_catalog     | pg_statio_sys_indexes           |
# | 180 | pg_catalog     | pg_statio_sys_sequences         |
# | 181 | pg_catalog     | pg_statio_sys_tables            |
# | 182 | pg_catalog     | pg_statio_user_indexes          |
# | 183 | pg_catalog     | pg_statio_user_sequences        |
# | 184 | pg_catalog     | pg_statio_user_tables           |
# | 185 | pg_catalog     | pg_statistic                    |
# | 186 | pg_catalog     | pg_statistic_ext                |
# | 187 | pg_catalog     | pg_statistic_ext_data           |
# | 188 | pg_catalog     | pg_stats                        |
# | 189 | pg_catalog     | pg_stats_ext                    |
# | 190 | pg_catalog     | pg_stats_ext_exprs              |
# | 191 | pg_catalog     | pg_subscription                 |
# | 192 | pg_catalog     | pg_subscription_rel             |
# | 193 | pg_catalog     | pg_tables                       |
# | 194 | pg_catalog     | pg_tablespace                   |
# | 195 | pg_catalog     | pg_timezone_abbrevs             |
# | 196 | pg_catalog     | pg_timezone_names               |
# | 197 | pg_catalog     | pg_transform                    |
# | 198 | pg_catalog     | pg_trigger                      |
# | 199 | pg_catalog     | pg_ts_config                    |
# | 200 | pg_catalog     | pg_ts_config_map                |
# | 201 | pg_catalog     | pg_ts_dict                      |
# | 202 | pg_catalog     | pg_ts_parser                    |
# | 203 | pg_catalog     | pg_ts_template                  |
# | 204 | pg_catalog     | pg_type                         |
# | 205 | pg_catalog     | pg_user                         |
# | 206 | pg_catalog     | pg_user_mapping                 |
# | 207 | pg_catalog     | pg_user_mappings                |
# | 208 | pg_catalog     | pg_views                        |
#
# |     | table_schema   | table_name      |
# |----:|:---------------|:----------------|
# | 209 | public         | aircrafts       |
# | 210 | public         | aircrafts_data  |
# | 211 | public         | airports        |
# | 212 | public         | airports_data   |
# | 213 | public         | boarding_passes |
# | 214 | public         | flights         |
# | 215 | public         | flights_v       |
# | 216 | public         | pilot_hobbies   |
# | 217 | public         | pilots          |
# | 218 | public         | public          |
# | 219 | public         | routes          |
# | 220 | public         | seats           |
# | 221 | public         | ticket_flights  |
# | 222 | public         | tickets         |

# %% [markdown]
# ### Создать таблицу

# %%
create_table_sql = """
CREATE TABLE public.example_table (
    id integer not null PRIMARY KEY,
    col1 text,
    col2 text,
    col3 text,
    col4 bool
);
CREATE unique index on public.example_table (id);
"""
conn = Postgres()
conn.execute(create_table_sql)
conn.close()

# %% [markdown]
# ### Добавить запись в таблицу

# %%
def insert_test(element):
    if isinstance(element, str):
        return element.strip()
    return element

insert_into_sql = """
INSERT INTO public.example_table (
    id,
    col1,
    col2,
    col3,
    col4
) VALUES (%s,%s,%s,%s,%s);
"""

add = pd.DataFrame([
    [1, '1','A','a', False],
    [2, '2','B','b', True],
    [3, '3','C','c', False]
], columns = ['id','col1','col2','col3','col4'])

conn = Postgres()

for row in add.values:
    display(row)
    conn.execute(insert_into_sql,
                 tuple(insert_test(element) for element in row))
    
conn.close()
# Out:
# array([1, '1', 'A', 'a', False], dtype=object)
# array([2, '2', 'B', 'b', True], dtype=object)
# array([3, '3', 'C', 'c', False], dtype=object)

# %% [markdown]
# ### Получить данные из таблицы

# %%
select_sql = """
SELECT * 
FROM public.example_table;

"""

conn = Postgres()
data = pd.DataFrame(
    conn.fetchall(select_sql)
    )
conn.close()

data
# Out:
#    id  col1 col2 col3   col4
# 0   1     1    A    a  False
# 1   2     2    B    b   True
# 2   3     3    C    c  False

# %% [markdown]
# ### Изменить таблицу

# %%
alter_table_sql = """
ALTER TABLE public.example_table
ALTER COLUMN col1 TYPE integer USING col1::integer;
"""

conn = Postgres()
conn.execute(alter_table_sql)
conn.close()

# %% [markdown]
# ### Удалить записи из таблицы

# %%
delete_values_sql = """
DELETE from public.example_table
WHERE col4 = True;
"""

conn = Postgres()
conn.execute(delete_values_sql)
conn.close()

# %% [markdown]
# ### Удалить таблицу

# %%
drop_table_sql = """DROP table public.example_table;"""

conn = Postgres()
conn.execute(drop_table_sql)
conn.close()
